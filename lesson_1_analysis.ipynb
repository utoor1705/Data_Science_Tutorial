# %%
import pandas as pd
import matplotlib.pyplot as plt 
from pandas.plotting import scatter_matrix

# %%
# Read the data
df = pd.read_csv('California_Housing_Data_Part1.csv')

# Information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   housing_median_age  999 non-null    int64
#  1   total_rooms         999 non-null    int64
#  2   population          999 non-null    int64
#  3   households          999 non-null    int64
#  4   median_income       999 non-null    float64
#  5   median_house_value  999 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 47.0 KB

# %%
# Describe the data
df.describe()
# Out:
#        housing_median_age   total_rooms    population   households  \
# count          999.000000    999.000000    999.000000   999.000000
# mean            37.517518   2385.512513   1219.436436   461.623624
# std             13.166478   2058.883961    997.101458   365.691763
# min              2.000000     12.000000     18.000000     7.000000
# 25%             28.000000   1261.500000    661.500000   253.000000
# 50%             39.000000   1897.000000    968.000000   367.000000
# 75%             51.000000   2852.500000   1449.500000   539.000000
# max             52.000000  28258.000000  12203.000000  3701.000000
#
#        median_income  median_house_value
# count     999.000000          999.000000
# mean        3.841898       209500.412412
# std         1.811925        89080.579540
# min         0.499900        60000.000000
# 25%         2.562500       148400.000000
# 50%         3.512500       195200.000000
# 75%         4.883650       254200.000000
# ...

# %%
# Create Correlation Matrix and Make Scatter Plots
scatter_matrix(df, figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='housing_median_age', ylabel='housing_median_age'>,
#         <Axes: xlabel='total_rooms', ylabel='housing_median_age'>,
#         <Axes: xlabel='population', ylabel='housing_median_age'>,
#         <Axes: xlabel='households', ylabel='housing_median_age'>,
#         <Axes: xlabel='median_income', ylabel='housing_median_age'>,
#         <Axes: xlabel='median_house_value', ylabel='housing_median_age'>],
#        [<Axes: xlabel='housing_median_age', ylabel='total_rooms'>,
#         <Axes: xlabel='total_rooms', ylabel='total_rooms'>,
#         <Axes: xlabel='population', ylabel='total_rooms'>,
#         <Axes: xlabel='households', ylabel='total_rooms'>,
#         <Axes: xlabel='median_income', ylabel='total_rooms'>,
#         <Axes: xlabel='median_house_value', ylabel='total_rooms'>],
#        [<Axes: xlabel='housing_median_age', ylabel='population'>,
#         <Axes: xlabel='total_rooms', ylabel='population'>,
# ...

# %%
# Find correlation with respect to median house value
df.corr()['median_house_value'].sort_values()
# Out:
# housing_median_age   -0.138196
# population            0.151646
# households            0.176037
# total_rooms           0.305802
# median_income         0.766627
# median_house_value    1.000000
# Name: median_house_value, dtype: float64
